# %% [markdown]
# <a href="https://colab.research.google.com/github/Sahita9/Visualization-using-plotly/blob/main/Plotly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dash
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 20.1 MB/s eta 0:00:00
# ...

# %%
from dash import Dash, dcc, html, Input, Output
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv('/content/drive/MyDrive/clean_startup_data_replace.csv',index_col=0)
df.head()
# Out:
#   state_code   latitude   longitude  zip_code       id           city  \
# 0         CA  42.358880  -71.056820     92101   c:6669      San Diego
# 1         CA  37.238916 -121.973718     95032  c:16283      Los Gatos
# 2         CA  32.901049 -117.192656     92121  c:65620      San Diego
# 3         CA  37.320309 -122.050040     95014  c:42668      Cupertino
# 4         CA  37.779281 -122.419236     94105  c:65806  San Francisco
#
#                 name  labels  founded_at   closed_at  ... object_id has_VC  \
# 0        Bandsintown    True  2007-01-01  2007-01-01  ...    c:6669  False
# 1          TriCipher    True  2000-01-01  2000-01-01  ...   c:16283   True
# 2              Plixi    True  2009-03-18  2009-03-18  ...   c:65620  False
# 3  Solidcore Systems    True  2002-01-01  2002-01-01  ...   c:42668  False
# 4     Inhale Digital   False  2010-08-01  2012-10-01  ...   c:65806   True
#
#    has_angel  has_roundA  has_roundB  has_roundC  has_roundD  \
# ...

# %%
app= Dash(__name__)
hist_list=list()
hist_list=df.columns[12:20].tolist()
hist_list.append(df.columns[-3])


app.layout=html.Div(children= [
    html.H1('Visualizing Data -Exploartory Data Analysis of Startup data'),
    html.P('Select the variable that ou what to see the distribution for'),
    dcc.Dropdown(
        id='hist_column',
        options=hist_list,
        value=hist_list[0],
        clearable=False,
        style= {
            'width':'50%',
            'color':'blue',
            'font-size':'16px',
            'margin-bottom':'10px'
        }
    ),
    dcc.Graph(id='histogram')
    ])
@app.callback(
    Output('histogram','figure'),
    Input('hist_column','value')
)
def histogram(hist_column):
  fig_hist=px.histogram(df,x= hist_column, color='status')
  fig_hist.update_layout(title_text='Distribution of'+ hist_column)
  return fig_hist

app.run(jupyter_mode ='external')
# Out:
# Dash app running on:

# %%
pp = Dash(__name__)
hist_list = list()
hist_list = df.columns[12:20].tolist()
hist_list.append(df.columns[-3])
scatter_list=list()
scatter_list = df.columns[12:20].tolist()
scatter_list.append(df.columns[-3])

app.layout = html.Div(children = [
    html.H1('Visualizing data - Exploratory data analyis of startup data'),
    html.P('Select the variable that you want the distribution for : '),
    dcc.Dropdown(
    id = 'hist_column',
    options = hist_list,
    value = hist_list[0],
        clearable = False,
        style={
            'width' : '50%',
            'color' : 'blue',
            'font-size' : '16px',
            'margian-bottom' : '10px'
        }
    ),
    dcc.Graph(id = 'histogram'),
    html.P('Select the x variable'),
    dcc.Dropdown(
        id='x',
        options=scatter_list,
        value=scatter_list[0],
        style = {
            'width' : '50%',
            'color' : 'blue',
            'font-size' : '16px',
            'margin-bottom' : '10px'
        }

    ),
    html.P('Select the y variable'),
    dcc.Dropdown(
        id='y',
        options=scatter_list,
        value=scatter_list[1],
        style = {
            'width' : '50%',
            'color' : 'blue',
            'font-size' : '16px',
            'margin-bottom' : '10px'
        }
    ),
    dcc.Graph(id='scatter_plot')
])
@app.callback(
    Output('histogram', 'figure'),
    Input('hist_column' , 'value')
)
def histogram(hist_column):
    fig_hist = px.histogram(df, x = hist_column, color = 'status')
    fig_hist.update_layout(title_text = 'Distribution of ' + hist_column)
    return fig_hist
@app.callback(
    Output('scatter_plot', 'figure'),
    Input('x', 'value'),
    Input('y', 'value')
)
def scatter(x,y):
  fig_scatter = px.scatter(df, x=x ,y=y , color ='status')
  return fig_scatter




app.run(jupyter_mode = 'external')
# Out:
# Dash app running on:
